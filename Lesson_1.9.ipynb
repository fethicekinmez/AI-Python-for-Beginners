# %% [markdown]
# # L9: Building LLM prompts with variables

# %% [markdown]
# In the next cell, you will import the function `print_llm_response` that uses an LLM with an instruction that you provide as a string and displays the result.

# %%
from helper_functions import print_llm_response

# %% [markdown]
# Basically, you can use that function as if you were asking a chatbot. You just need to provide your instructions as a string. For instance, you can ask "What is the capital of France?" using the following code:

# %%
print_llm_response("What is the capital of Turkey?")
# Out:
# The capital of Turkey is Ankara.

# %% [markdown]
# Let's ask the LLM for the lifestyle description for Otto Matic, whose name is stored in `name`, if he were a `dog_age` years old dog.

# %%
name = "Otto Matic"
dog_age = 21/7

# %%
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior.""")
# Out:
# At 3.0 years old, a dog is in the prime of adulthood. This life stage typically features high energy levels, strong physical health, and full maturity. The dog would be active, playful, and curious, enjoying regular exercise and mental stimulation. Behavior-wise, it would be confident, well-socialized, and responsive to training, with interests in play, exploration, and social interaction.

# %% [markdown]
# <b>You just used AI with your own variables!</b> You used an LLM with instructions that included variables you defined in this notebook.
#
# <b>Congratulations 🎉🎉🎉</b>

# %% [markdown]
# ## Variable names restrictions

# %% [markdown]
# The following variable names also have some problems. Try to fix them yourself or use the help from the chatbot.

# %%
driver = "unicorn"
driver's vehicle = "colorful, asymmetric dinosaur car"
favorite planet = "Pluto
# Out:
#   Cell In [6], line 2
#     driver's vehicle = "colorful, asymmetric dinosaur car"
#                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
driver = "unicorn"
drivers_vehicle = "colorful, asymmetric dinosaur car"
favorite_planet = "Pluto"

# %% [markdown]
# Now, update the next cell with any changes you made in the previous cell.

# %%
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing
a {drivers_vehicle} for the {favorite_planet} champion cup.""")
# Out:
# In the magical land of Glitterville, the biggest event was the Pluto Champion Cup—a race like no other! This year, the two fastest racers were Luna the unicorn and DinoDash, a colorful, asymmetric dinosaur car.
#
# Luna was graceful and swift, her silver mane sparkling in the sunlight. DinoDash was bright green with purple spots, one big wheel in front, and two smaller wheels in the back. Though he looked a little wobbly, DinoDash was super fast!
#
# The race began at the Rainbow Bridge and ended at the Crystal Castle. The crowd cheered as Luna galloped ahead, her hooves barely touching the ground. DinoDash roared to life, his engine humming with excitement.
#
# At first, Luna led the way, her horn glowing with magic. But DinoDash zoomed past with a burst of speed, his uneven wheels spinning wildly. Around the Twinkle Trees, Luna used her magic to leap over fallen branches, while DinoDash carefully zigzagged through the narrow path.
#
# Near the Glittering Lake, DinoDash’s engine sputtered. Luna slowed down and called out, “Need some help, DinoDash?” With a smile, she used her magic to fix his engine. “Thank you!” DinoDash beeped happily.
#
# Together, they raced side by side toward the finish line. The crowd held their breath as Luna and DinoDash crossed the line at the same time!
#
# The judges smiled and said, “This year, the Pluto Champion Cup goes to both Luna and DinoDash—for teamwork and friendship!”
#
# Luna and DinoDash high-fived (and hoofed) happily. They learned that winning was fun, but sharing the race with a friend was the best prize of all.

# %% [markdown]
# ## Extra practice
#
# Try the exercises below to practice the concepts from this lesson. Read the comments in each cell with the instructions for each exercise.
#
# <b>Feel free to use the chatbot if you need help.</b>

# %%
# Fix this code
1favorite-book = "1001 Ways to Wear a Hat"
"2002 Ways to Wear a Scarf" = second_fav_book
print(f"My most favorite book is {1favorite-book}, but I also like {second_fav_book})
# Out:
#   Cell In [11], line 2
#     1favorite-book = "1001 Ways to Wear a Hat"
#      ^
# SyntaxError: invalid syntax

# %%
# Fix this code
favorite_book = "1001 Ways to Wear a Hat"
second_fav_book = "2002 Ways to Wear a Scarf"
print(f"My most favorite book is {favorite_book}, but I also like {second_fav_book}")
# Out:
# My most favorite book is 1001 Ways to Wear a Hat, but I also like 2002 Ways to Wear a Scarf

# %%
favorite_game = "The Legend of Zelda: Breath of the Wild"
favorite_movie = "Inception"
favorite_food = "Sushi"

print_llm_response(f"""
My favorite game is {favorite_game}, my favorite movie is {favorite_movie}, and my favorite food is {favorite_food}.
Based on these preferences, please recommend one new song I should listen to and explain briefly why you chose it.
""")
# Out:
# Try "Time" by Hans Zimmer. It matches the epic, immersive feel of Breath of the Wild and the mind-bending depth of Inception, while its smooth, layered composition complements the refined taste suggested by your love of sushi.
